# %%
import statsmodels.api as sm
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import keras
from keras import models
from keras import layers
from keras import optimizers
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dropout
from sklearn import linear_model
from keras.layers import Dense, Dropout
from math import sqrt
import tensorflow as tf
# Out:
# Using TensorFlow backend.

# %%
df=pd.read_csv('C:/Users/Xi/Documents/MobaXterm/home/Bikeshare/Bikeshare/Data/hourly.csv')

# %% [markdown]
# ## EDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  object
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: float64(4), int64(12), object(1)
# memory usage: 2.3+ MB

# %%
df.season=df.season.astype('object')
df.holiday =df.holiday .astype('object')
df.yr=df.yr.astype('object')
df.workingday=df.workingday.astype('object')
df.weathersit=df.weathersit.astype('object')
df.cnt=df.cnt.astype('float64')

# %% [markdown]
# #### Checking NA.

# %%
df.isnull().any()
# Out:
# instant       False
# dteday        False
# season        False
# yr            False
# mnth          False
# hr            False
# holiday       False
# weekday       False
# workingday    False
# weathersit    False
# temp          False
# atemp         False
# hum           False
# windspeed     False
# casual        False
# registered    False
# cnt           False
# dtype: bool

# %% [markdown]
# ## Data wrangling.

# %% [markdown]
# #### Spliting dataset to train and test set so we can evaluate the model performance once trained.

# %%
X_train, X_test, y_train, y_test = train_test_split(df.drop('cnt',axis=1),df['cnt'], random_state=123, test_size=0.2)
X_train.index=range(len(X_train))
X_test.index=range(len(X_test))
y_train.index=range(len(y_train))
y_test.index=range(len(y_test))
print('Dimension of the training input is:', X_train.shape)
print('Dimension of the test input is:', X_test.shape)
print('Dimension of the training output is:', y_train.shape)
print('Dimension of the test output is:', y_test.shape)
# Out:
# Dimension of the training input is: (13903, 16)
# Dimension of the test input is: (3476, 16)
# Dimension of the training output is: (13903,)
# Dimension of the test output is: (3476,)

# %%
train=pd.concat((X_train,y_train),axis=1)

# %%
train.loc[:,('mnth','weekday','hr','weathersit','temp','atemp','hum','windspeed','cnt')].corr()
# Out:
#                mnth   weekday        hr      temp     atemp       hum  \
# mnth       1.000000  0.010570 -0.004891  0.202585  0.209034  0.166314
# weekday    0.010570  1.000000 -0.001389  0.002954 -0.004522 -0.041397
# hr        -0.004891 -0.001389  1.000000  0.138506  0.134413 -0.274225
# temp       0.202585  0.002954  0.138506  1.000000  0.988389 -0.070318
# atemp      0.209034 -0.004522  0.134413  0.988389  1.000000 -0.052080
# hum        0.166314 -0.041397 -0.274225 -0.070318 -0.052080  1.000000
# windspeed -0.131018  0.015024  0.138242 -0.019874 -0.060280 -0.286817
# cnt        0.121758  0.031255  0.397320  0.407580  0.404321 -0.324243
#
#            windspeed       cnt
# mnth       -0.131018  0.121758
# weekday     0.015024  0.031255
# hr          0.138242  0.397320
# temp       -0.019874  0.407580
# atemp      -0.060280  0.404321
# hum        -0.286817 -0.324243
# windspeed   1.000000  0.089119
# cnt         0.089119  1.000000

# %% [markdown]
# #### numerical significant variable: hr,temp,atemp.But temp and atemp are very correlated to each other. so pick one, temp.

# %%
X=train[['temp','hr','season','holiday','yr','workingday','weathersit']]
y=train['cnt']
X=pd.get_dummies(X)
X.drop('holiday_0', axis=1, inplace=True) #To avoid multi-colinearity, we drop one of the dummy columns.
X.rename(columns={'holiday_1': 'holiday'}, inplace=True)
X.drop('yr_0', axis=1, inplace=True)
X.rename(columns={'yr_1': 'yr'}, inplace=True)
X.drop('workingday_0', axis=1, inplace=True)
X.rename(columns={'workingday_1': 'workingday'}, inplace=True)
X.drop('season_4', axis=1, inplace=True)
X.drop('weathersit_4', axis=1, inplace=True)

# %%
X2=sm.add_constant(X)
model = sm.OLS(y, X2).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cnt   R-squared:                       0.372
# Model:                            OLS   Adj. R-squared:                  0.372
# Method:                 Least Squares   F-statistic:                     748.2
# Date:                Fri, 01 May 2020   Prob (F-statistic):               0.00
# Time:                        13:44:04   Log-Likelihood:                -88769.
# No. Observations:               13903   AIC:                         1.776e+05
# Df Residuals:                   13891   BIC:                         1.777e+05
# Df Model:                          11
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const         -119.9695     83.025     -1.445      0.148    -282.710      42.772
# temp           393.4353     10.580     37.186      0.000     372.697     414.174
# hr               8.9409      0.181     49.316      0.000       8.586       9.296
# season_1       -42.2455      3.717    -11.365      0.000     -49.532     -34.959
# season_2       -39.5643      3.699    -10.696      0.000     -46.815     -32.314
# season_3       -79.2766      4.579    -17.313      0.000     -88.252     -70.301
# holiday        -21.5954      7.640     -2.827      0.005     -36.570      -6.620
# yr              84.7610      2.441     34.717      0.000      79.975      89.547
# workingday       3.4343      2.707      1.269      0.205      -1.872       8.741
# weathersit_1    17.9338     82.904      0.216      0.829    -144.570     180.437
# weathersit_2     1.5228     82.922      0.018      0.985    -161.015     164.061
# weathersit_3   -58.3091     82.996     -0.703      0.482    -220.993     104.375
# ==============================================================================
# Omnibus:                     2477.971   Durbin-Watson:                   2.013
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4567.653
# Skew:                           1.120   Prob(JB):                         0.00
# Kurtosis:                       4.694   Cond. No.                     1.84e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.84e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# #### working day and weathersit are insignificant (pvalue>0.05), so we want to drop it from the X.

# %%
X.drop('workingday',axis=1,inplace=True)
X.drop('weathersit_1',axis=1,inplace=True)
X.drop('weathersit_2',axis=1,inplace=True)
X.drop('weathersit_3',axis=1,inplace=True)

# %%
X_test1=X_test[['temp','season','holiday','yr','hr']]

# %%
X_test1=pd.get_dummies(X_test1)

# %%
X_test1.drop('season_4', axis=1, inplace=True)
X_test1.drop('holiday_0', axis=1, inplace=True) #To avoid multi-colinearity, we drop one of the dummy columns.
X_test1.rename(columns={'holiday_1': 'holiday'}, inplace=True)
X_test1.drop('yr_0', axis=1, inplace=True)
X_test1.rename(columns={'yr_1': 'yr'}, inplace=True)

# %% [markdown]
# #### Dataset has already been normalized so no need to do it again.

# %% [markdown]
# ## linear regression Model

# %%
lm = linear_model.LinearRegression()
model = lm.fit(X,y)

# %%
predictions = lm.predict(X_test1)
lm.score(X,y) #R-square
# Out:
# 0.3591453123793976

# %%
summation=0
for i in range (0,len(y_test)):  #looping through each element of the list
    difference = predictions[i] - y_test[i]  #finding the difference between observed and predicted value
    squared_difference = difference**2  #taking square of the differene 
    summation = summation + squared_difference  #taking a sum of all the differences
RMSE = sqrt(summation/len(y_test))
RMSE
# Out:
# 149.2668402668126

# %%
plt.figure(figsize=(12,6))
plt.plot(y_test)
plt.plot(predictions)
plt.title('True vs. Predictions')
plt.ylabel('CNT')
plt.xlabel('Samples')
plt.legend(['Actual', 'Predictions'], loc='upper left')
plt.show()

# %% [markdown]
# ## DNN Model

# %%
X=X.to_numpy()
X_test2=X_test1.to_numpy()

# %%
y_train=y_train.to_numpy()
y_test=y_test.to_numpy()

# %%
X=X.reshape(X.shape[0],X.shape[1])
X_test2=X_test2.reshape(X_test2.shape[0],X_test2.shape[1])
print('Dimension of the training input is:', X.shape)
print('Dimension of the test input is:', X_test2.shape)
# Out:
# Dimension of the training input is: (13903, 7)
# Dimension of the test input is: (3476, 7)

# %%
np.random.seed(123)
tf.random.set_seed(123)
modeldnn=Sequential()
modeldnn.add(Dense(45,activation ='relu',input_dim=7))
modeldnn.add(Dropout(0.5))
modeldnn.add(Dense(45,activation='relu'))
modeldnn.add(Dropout(0.5))
modeldnn.add(Dense(45,activation='relu'))
modeldnn.add(Dropout(0.2))
modeldnn.add(Dense(1,activation='linear'))
modeldnn.compile(loss='mse',optimizer='adam',metrics=['mean_squared_error'])
network=modeldnn.fit(X,y_train,epochs=30,validation_split=1/6,batch_size=6,verbose=1)
# Out:
# Train on 11585 samples, validate on 2318 samples
# Epoch 1/30
# 11585/11585 [==============================] - 3s 232us/step - loss: 30282.4503 - mean_squared_error: 30282.4473 - val_loss: 23548.7965 - val_mean_squared_error: 23548.8047
# Epoch 2/30
# 11585/11585 [==============================] - 2s 213us/step - loss: 25541.6585 - mean_squared_error: 25541.6602 - val_loss: 20284.2306 - val_mean_squared_error: 20284.2285
# Epoch 3/30
# 11585/11585 [==============================] - 3s 228us/step - loss: 22992.9121 - mean_squared_error: 22992.9277 - val_loss: 17975.8663 - val_mean_squared_error: 17975.8633
# Epoch 4/30
# 11585/11585 [==============================] - 3s 225us/step - loss: 21683.3405 - mean_squared_error: 21683.3320 - val_loss: 16939.4819 - val_mean_squared_error: 16939.4805
# Epoch 5/30
# 11585/11585 [==============================] - 2s 209us/step - loss: 19925.2395 - mean_squared_error: 19925.2363 - val_loss: 15739.9355 - val_mean_squared_error: 15739.9365
# Epoch 6/30
# 11585/11585 [==============================] - 3s 221us/step - loss: 18636.3506 - mean_squared_error: 18636.3730 - val_loss: 15578.0055 - val_mean_squared_error: 15578.0117
# Epoch 7/30
# 11585/11585 [==============================] - 3s 219us/step - loss: 18408.7113 - mean_squared_error: 18408.7051 - val_loss: 14753.5824 - val_mean_squared_error: 14753.5820
# Epoch 8/30
# 11585/11585 [==============================] - 3s 237us/step - loss: 17652.3674 - mean_squared_error: 17652.3750 - val_loss: 14811.4498 - val_mean_squared_error: 14811.4512
# Epoch 9/30
# 11585/11585 [==============================] - 3s 225us/step - loss: 17400.9021 - mean_squared_error: 17400.9102 - val_loss: 14707.6392 - val_mean_squared_error: 14707.6406
# Epoch 10/30
# 11585/11585 [==============================] - 3s 230us/step - loss: 17147.0459 - mean_squared_error: 17147.0293 - val_loss: 14209.5827 - val_mean_squared_error: 14209.5791
# Epoch 11/30
# 11585/11585 [==============================] - 3s 259us/step - loss: 17155.1068 - mean_squared_error: 17155.0918 - val_loss: 14114.5127 - val_mean_squared_error: 14114.5146
# Epoch 12/30
# 11585/11585 [==============================] - 3s 248us/step - loss: 17073.4947 - mean_squared_error: 17073.4922 - val_loss: 14330.7324 - val_mean_squared_error: 14330.7275
# Epoch 13/30
# 11585/11585 [==============================] - 3s 232us/step - loss: 17321.4634 - mean_squared_error: 17321.4473 - val_loss: 14293.7553 - val_mean_squared_error: 14293.7500
# Epoch 14/30
# 11585/11585 [==============================] - 3s 224us/step - loss: 16831.4829 - mean_squared_error: 16831.4883 - val_loss: 14478.3508 - val_mean_squared_error: 14478.3486
# Epoch 15/30
# 11585/11585 [==============================] - 3s 226us/step - loss: 16915.9785 - mean_squared_error: 16916.0020 - val_loss: 14492.6965 - val_mean_squared_error: 14492.6953
# Epoch 16/30
# 11585/11585 [==============================] - 3s 224us/step - loss: 16949.6916 - mean_squared_error: 16949.7148 - val_loss: 14030.9329 - val_mean_squared_error: 14030.9287
# Epoch 17/30
# 11585/11585 [==============================] - 3s 229us/step - loss: 16968.2978 - mean_squared_error: 16968.3105 - val_loss: 13930.9337 - val_mean_squared_error: 13930.9336
# Epoch 18/30
# 11585/11585 [==============================] - 2s 200us/step - loss: 16613.5815 - mean_squared_error: 16613.5742 - val_loss: 14051.4745 - val_mean_squared_error: 14051.4756
# Epoch 19/30
# 11585/11585 [==============================] - 2s 180us/step - loss: 16645.6988 - mean_squared_error: 16645.6855 - val_loss: 13855.2127 - val_mean_squared_error: 13855.2119
# Epoch 20/30
# 11585/11585 [==============================] - 2s 171us/step - loss: 16663.6141 - mean_squared_error: 16663.6250 - val_loss: 14016.2778 - val_mean_squared_error: 14016.2764
# Epoch 21/30
# 11585/11585 [==============================] - 2s 174us/step - loss: 16745.3222 - mean_squared_error: 16745.3145 - val_loss: 14347.8988 - val_mean_squared_error: 14347.8994
# Epoch 22/30
# 11585/11585 [==============================] - 2s 197us/step - loss: 16760.9036 - mean_squared_error: 16760.9082 - val_loss: 13770.2218 - val_mean_squared_error: 13770.2188
# Epoch 23/30
# 11585/11585 [==============================] - 2s 168us/step - loss: 16778.2333 - mean_squared_error: 16778.2344 - val_loss: 13831.4301 - val_mean_squared_error: 13831.4316
# Epoch 24/30
# 11585/11585 [==============================] - 2s 189us/step - loss: 16387.3138 - mean_squared_error: 16387.3027 - val_loss: 13597.6266 - val_mean_squared_error: 13597.6230
# Epoch 25/30
# 11585/11585 [==============================] - 2s 180us/step - loss: 16216.7942 - mean_squared_error: 16216.7861 - val_loss: 13970.6501 - val_mean_squared_error: 13970.6553
# Epoch 26/30
# 11585/11585 [==============================] - 2s 190us/step - loss: 16773.2106 - mean_squared_error: 16773.2188 - val_loss: 13994.0148 - val_mean_squared_error: 13994.0176
# Epoch 27/30
# 11585/11585 [==============================] - 2s 189us/step - loss: 16614.6102 - mean_squared_error: 16614.6191 - val_loss: 13729.4599 - val_mean_squared_error: 13729.4609
# Epoch 28/30
# 11585/11585 [==============================] - 2s 190us/step - loss: 16963.3446 - mean_squared_error: 16963.3457 - val_loss: 13639.8302 - val_mean_squared_error: 13639.8262
# Epoch 29/30
# 11585/11585 [==============================] - 2s 184us/step - loss: 16547.1336 - mean_squared_error: 16547.1250 - val_loss: 13718.3792 - val_mean_squared_error: 13718.3789
# Epoch 30/30
# 11585/11585 [==============================] - 2s 185us/step - loss: 16665.9259 - mean_squared_error: 16665.9414 - val_loss: 13552.6504 - val_mean_squared_error: 13552.6504

# %%
plt.figure(figsize=(12,6))
plt.plot(network.history['loss'],label='loss')
plt.plot(network.history['val_loss'],label='val loss')
plt.legend()
plt.show()

# %%
evaval=network.history['val_loss'][29]
print('The rmse for the validation is', sqrt(evaval))
# Out:
# The rmse for the validation is 116.41585110371591

# %%
eva=modeldnn.evaluate(X_test2,y_test)
print('The rmse for the test set is', sqrt(eva[1]))
# Out:
# 3476/3476 [==============================] - 0s 16us/step
# The rmse for the test set is 117.7812914566125

# %%
plt.figure(figsize=(12,6))
preds=modeldnn.predict(X_test2)
plt.plot(y_test,label='Actual')
plt.plot(preds,label='Predicted',color='orange')
plt.legend()
plt.show()

# %% [markdown]
# #### We can tell from the output is that using DNN and linear regression has a comparable performance, but DNN gives a lower RMSE compared to linear regression. Even though the R-squared is not high in linear regression model, it does not mean that the model is not good enought as we can see that the RMSE is cmparable to DNN.
